# %%
# !mkdir dataset
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/8 -P dataset # dichasus-cf02
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/9 -P dataset # dichasus-cf03
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/10 -P dataset # dichasus-cf04
# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf02.json -P dataset
# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf03.json -P dataset
# !wget -nc https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf04.json -P dataset
# !wget -nc --content-disposition https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/1 -P dataset # spec.json
# Out:
# --2023-10-18 14:49:01--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/8
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/1811e4e178e-eb04ebca7449?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf02.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231018T144603Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20231018%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=566d700b002561157d347bd047d652890ea8751a40b203383573e274236dd8b7 [following]
# --2023-10-18 14:49:01--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/1811e4e178e-eb04ebca7449?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf02.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231018T144603Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20231018%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=566d700b002561157d347bd047d652890ea8751a40b203383573e274236dd8b7
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.99, 129.69.5.100, 2001:7c0:2041:1db::99, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4862708952 (4.5G) [application/octet-stream]
# Saving to: ‘dataset/dichasus-cf02.tfrecords’
#
# dichasus-cf02.tfrec 100%[===================>]   4.53G  35.1MB/s    in 2m 30s
#
# 2023-10-18 14:51:31 (30.9 MB/s) - ‘dataset/dichasus-cf02.tfrecords’ saved [4862708952/4862708952]
#
# --2023-10-18 14:51:31--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/9
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/1811e4ffaa7-444e1e441a38?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf03.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231018T144833Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20231018%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=3fc165a2616de21a58c01974419606aa59c442ae71b26a8426466a0ccf2a5673 [following]
# --2023-10-18 14:51:32--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/1811e4ffaa7-444e1e441a38?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf03.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231018T144833Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20231018%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=3fc165a2616de21a58c01974419606aa59c442ae71b26a8426466a0ccf2a5673
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.99, 129.69.5.100, 2001:7c0:2041:1db::99, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.99|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 6165839316 (5.7G) [application/octet-stream]
# Saving to: ‘dataset/dichasus-cf03.tfrecords’
#
# dichasus-cf03.tfrec 100%[===================>]   5.74G  31.9MB/s    in 2m 52s
#
# 2023-10-18 14:54:24 (34.1 MB/s) - ‘dataset/dichasus-cf03.tfrecords’ saved [6165839316/6165839316]
#
# --2023-10-18 14:54:24--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/10
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/1811e532723-5913ded52ae6?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf04.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231018T145126Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20231018%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=86737da3f71971f1a148c6751c5d0a8e8a3bf10117ae3859428de56695770a0e [following]
# --2023-10-18 14:54:24--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/1811e532723-5913ded52ae6?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27dichasus-cf04.tfrecords&response-content-type=application%2Foctet-stream&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231018T145126Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20231018%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=86737da3f71971f1a148c6751c5d0a8e8a3bf10117ae3859428de56695770a0e
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.100, 129.69.5.99, 2001:7c0:2041:1db::99, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 11027760402 (10G) [application/octet-stream]
# Saving to: ‘dataset/dichasus-cf04.tfrecords’
#
# dichasus-cf04.tfrec 100%[===================>]  10.27G  25.0MB/s    in 6m 31s
#
# 2023-10-18 15:00:55 (26.9 MB/s) - ‘dataset/dichasus-cf04.tfrecords’ saved [11027760402/11027760402]
#
# --2023-10-18 15:00:56--  https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf02.json
# Resolving dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)... 129.69.175.114
# Connecting to dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)|129.69.175.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1836 (1.8K) [application/json]
# Saving to: ‘dataset/reftx-offsets-dichasus-cf02.json’
#
# reftx-offsets-dicha 100%[===================>]   1.79K  --.-KB/s    in 0s
#
# 2023-10-18 15:00:56 (197 MB/s) - ‘dataset/reftx-offsets-dichasus-cf02.json’ saved [1836/1836]
#
# --2023-10-18 15:00:56--  https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf03.json
# Resolving dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)... 129.69.175.114
# Connecting to dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)|129.69.175.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1830 (1.8K) [application/json]
# Saving to: ‘dataset/reftx-offsets-dichasus-cf03.json’
#
# reftx-offsets-dicha 100%[===================>]   1.79K  --.-KB/s    in 0s
#
# 2023-10-18 15:00:56 (200 MB/s) - ‘dataset/reftx-offsets-dichasus-cf03.json’ saved [1830/1830]
#
# --2023-10-18 15:00:56--  https://dichasus.inue.uni-stuttgart.de/datasets/data/dichasus-cf0x/reftx-offsets-dichasus-cf04.json
# Resolving dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)... 129.69.175.114
# Connecting to dichasus.inue.uni-stuttgart.de (dichasus.inue.uni-stuttgart.de)|129.69.175.114|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1825 (1.8K) [application/json]
# Saving to: ‘dataset/reftx-offsets-dichasus-cf04.json’
#
# reftx-offsets-dicha 100%[===================>]   1.78K  --.-KB/s    in 0s
#
# 2023-10-18 15:00:56 (264 MB/s) - ‘dataset/reftx-offsets-dichasus-cf04.json’ saved [1825/1825]
#
# --2023-10-18 15:00:56--  https://darus.uni-stuttgart.de/api/access/datafile/:persistentId?persistentId=doi:10.18419/darus-2854/1
# Resolving darus.uni-stuttgart.de (darus.uni-stuttgart.de)... 129.69.7.87, 2001:7c0:2041:17f::87
# Connecting to darus.uni-stuttgart.de (darus.uni-stuttgart.de)|129.69.7.87|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/1811417c2f2-9d9ee9dc2fe4?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27spec.json&response-content-type=application%2Fjson&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231018T145758Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20231018%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=24c0b3acbd85b5209a4f906a1a6bd10919b3e898dfe0bbe03813041c182c71c0 [following]
# --2023-10-18 15:00:56--  https://s3.tik.uni-stuttgart.de/fokus-dv-prod-2/10.18419/darus-2854/1811417c2f2-9d9ee9dc2fe4?response-content-disposition=attachment%3B%20filename%2A%3DUTF-8%27%27spec.json&response-content-type=application%2Fjson&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Date=20231018T145758Z&X-Amz-SignedHeaders=host&X-Amz-Expires=172800&X-Amz-Credential=ZYFB5FYVYI021REQFP7K%2F20231018%2Fdataverse%2Fs3%2Faws4_request&X-Amz-Signature=24c0b3acbd85b5209a4f906a1a6bd10919b3e898dfe0bbe03813041c182c71c0
# Resolving s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)... 129.69.5.100, 129.69.5.99, 2001:7c0:2041:1db::99, ...
# Connecting to s3.tik.uni-stuttgart.de (s3.tik.uni-stuttgart.de)|129.69.5.100|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 3736 (3.6K) [application/json]
# Saving to: ‘dataset/spec.json’
#
# spec.json           100%[===================>]   3.65K  --.-KB/s    in 0s
#
# 2023-10-18 15:00:56 (1.31 GB/s) - ‘dataset/spec.json’ saved [3736/3736]
